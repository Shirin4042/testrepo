# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### Shirin Muhammed Faraz
#  Data Scientist

# %% [markdown]
#  _I am interested in data science because I would like to contriute towards affordable and quality healthcare in the future_

# %% [markdown]
# ### The following print "Hello World"

# %%
print ("Hello World")
# Out:
# Hello World

# %% [markdown]
# ***Number Names***
# 1. One
# 2. Two
# 3. Three
# 4. Four
# 5. Five
# [Visit IBM](https://cloud.ibm.com/)
# ![image.png](attachment:image.png)
